# %%
# 1️⃣ Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 2️⃣ Define repo and destination
repo_url = "https://github.com/RJLA/geemap-for-ge-students.git"  # 🔁 Replace this with the repo you want
destination = "/content/drive/MyDrive/Colab_Repos"  # You can change folder name if you want

# 3️⃣ Make sure destination folder exists
import os
os.makedirs(destination, exist_ok=True)

# 4️⃣ Clone the repository into Drive
# %cd $destination
# !git clone $repo_url

# 5️⃣ Verify contents
# !ls -l
# Out:
# test
